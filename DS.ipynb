# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# DS Practice

# %% [markdown]
# Hands on practice of DS course oursera

# %% [markdown]
# DS Languages
#    1.Python
#    2.R
#    3.Scala

# %% [markdown]
# DS Libraries
#     1.Pandas
#     2.Numpy
#     3.Matplotlib
#     4.GGplot

# %% [markdown]
# DS Tools
#     1.Apache spark
#     2.Hadoop
#     3.Snowflake

# %% [markdown]
# arithmetic operations
#     +,-, /, *

# %%
8 + 12 - 6 + 29
# Out:
# 43

# %%
mns = 200 
print(f"minutes : {mns}\nHours : {mns/60:.2f}")
# Out:
# minutes : 200
# Hours : 3.33

# %% [markdown]
# Unordered List
#     l= [2,3,1,4,5]

# %% [markdown]
# **Author
# Vinayak Sharma**
